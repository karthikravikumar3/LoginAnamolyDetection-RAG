# %%
from langchain_community.document_loaders import CSVLoader
loader = CSVLoader(file_path="LoginData.csv")

data = loader.load()

print(data)
# Out:
# [Document(metadata={'source': 'LoginData.csv', 'row': 0}, page_content='index: 0\nLogin Timestamp: 2020-02-03 12:43:30.772\nUser ID: -4324475583306591935\nRound-Trip Time [ms]: \nIP Address: 10.0.65.171\nCountry: NO\nRegion: -\nCity: -\nASN: 29695\nUser Agent String: Mozilla/5.0  (iPhone; CPU iPhone OS 13_4 like Mac OS X) Gecko/20150101 Firefox/20.0.0.1618 (Chrome variation/248113\nBrowser Name and Version: Firefox 20.0.0.1618\nOS Name and Version: iOS 13.4\nDevice Type: mobile\nLogin Successful: False\nIs Attack IP: False\nIs Account Takeover: False'), Document(metadata={'source': 'LoginData.csv', 'row': 1}, page_content='index: 1\nLogin Timestamp: 2020-02-03 12:43:43.549\nUser ID: -4324475583306591935\nRound-Trip Time [ms]: \nIP Address: 194.87.207.6\nCountry: AU\nRegion: -\nCity: -\nASN: 60117\nUser Agent String: Mozilla/5.0  (Linux; Android 4.1; Galaxy Nexus Build/JRN84D) AppleWebKit/537.36 (KHTML, like Gecko Chrome/46.0.2490.76 Mobile Safari/537.36 Browser\nBrowser Name and Version: Chrome Mobile 46.0.2490\nOS Name and Version: Android 4.1\nDevice Type: mobile\nLogin Successful: False\nIs Attack IP: False\nIs Account Takeover: False'), Document(metadata={'source': 'LoginData.csv', 'row': 2}, page_content='index: 2\nLogin Timestamp: 2020-02-03 12:43:55.873\nUser ID: -3284137479262433373\nRound-Trip Time [ms]: \nIP Address: 81.167.144.58\nCountry: NO\nRegion: Vestland\nCity: Urangsvag\nASN: 29695\nUser Agent String: Mozilla/5.0  (iPad; CPU OS 7_1 like Mac OS X) AppleWebKit/533.1 (KHTML, like Gecko Version/4.0 Mobile Safari/533.1 variation/277457\nBrowser Name and Version: Android 2.3.3.2672\nOS Name and Version: iOS 7.1\nDevice Type: mobile\nLogin Successful: True\nIs Attack IP: False\nIs Account Takeover: False'), Document(metadata={'source': 'LoginData.csv', 'row': 3}, page_content='index: 3\nLogin Timestamp: 2020-02-03 12:43:56.180\nUser ID: -4324475583306591935\nRound-Trip Time [ms]: \nIP Address: 170.39.78.152\nCountry: US\nRegion: -\nCity: -\nASN: 393398\nUser Agent String: Mozilla/5.0  (Linux; Android 4.1; Galaxy Nexus Build/JRN84D) Build/OPS27.82-19-4; wv AppleWebKit/537.36 (KHTML, like Gecko Version/4.0 Chrome/85.0.4183.127 Mobile Safari/537.36\nBrowser Name and Version: Chrome Mobile WebView 85.0.4183\nOS Name and Version: Android 4.1\nDevice Type: mobile\nLogin Successful: False\nIs Attack IP: False\nIs Account Takeover: False'), Document(metadata={'source': 'LoginData.csv', 'row': 4}, page_content='index: 4\nLogin Timestamp: 2020-02-03 12:43:59.396\nUser ID: -4618854071942621186\nRound-Trip Time [ms]: \nIP Address: 10.0.0.47\nCountry: US\nRegion: Virginia\nCity: Ashburn\nASN: 398986\nUser Agent String: Mozilla/5.0  (Linux; U; Android 2.2) Build/NMA26.42-169; wv AppleWebKit/537.36 (KHTML, like Gecko Version/4.0 Chrome/85.0.4183.120 Mobile Safari/537.36\nBrowser Name and Version: Chrome Mobile WebView 85.0.4183\nOS Name and Version: Android 2.2\nDevice Type: mobile\nLogin Successful: False\nIs Attack IP: True\nIs Account Takeover: False'), Document(metadata={'source': 'LoginData.csv', 'row': 5}, page_content='index: 5\nLogin Timestamp: 2020-02-03 12:44:05.160\nUser ID: -4324475583306591935\nRound-Trip Time [ms]: \nIP Address: 209.236.123.126\nCountry: US\nRegion: -\nCity: -\nASN: 393398\nUser Agent String: Mozilla/5.0  (Linux; Android 4.1; Galaxy Nexus Build/JRN84D) Build/NCQS26.69-64-5; wv AppleWebKit/537.36 (KHTML, like Gecko Version/4.0 Chrome/85.0.4183.127 Mobile Safari/537.36\nBrowser Name and Version: Chrome Mobile WebView 85.0.4183\nOS Name and Version: Android 4.1\nDevice Type: mobile\nLogin Successful: False\nIs Attack IP: True\nIs Account Takeover: False'), Document(metadata={'source': 'LoginData.csv', 'row': 6}, page_content='index: 6\nLogin Timestamp: 2020-02-03 12:44:07.893\nUser ID: 7246533443898239661\nRound-Trip Time [ms]: \nIP Address: 80.202.228.214\nCountry: NO\nRegion: -\nCity: -\nASN: 15659\nUser Agent String: Mozilla/5.066704189 Mozilla/5.0  (X11; CrOS x86_64 13020.67.3) AppleWebKit/537.36 (K ...

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (4.52.4)
# Requirement already satisfied: filelock in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers) (0.32.4)
# Requirement already satisfied: numpy>=1.17 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from requests->transformers) (2025.4.26)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-huggingface
# Out:
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.2.0-py3-none-any.whl.metadata (941 bytes)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from langchain-huggingface) (0.3.64)
# Collecting tokenizers>=0.19.1 (from langchain-huggingface)
#   Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting transformers>=4.39.0 (from langchain-huggingface)
#   Downloading transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# Collecting sentence-transformers>=2.6.0 (from langchain-huggingface)
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Collecting huggingface-hub>=0.30.2 (from langchain-huggingface)
#   Downloading huggingface_hub-0.32.4-py3-none-any.whl.metadata (14 kB)
# Collecting filelock (from huggingface-hub>=0.30.2->langchain-huggingface)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.30.2->langchain-huggingface)
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.9 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (6.0.2)
# Requirement already satisfied: requests in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.14.0)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.30.2->langchain-huggingface)
#   Downloading hf_xet-1.1.3-cp37-abi3-macosx_11_0_arm64.whl.metadata (879 bytes)
# Requirement already satisfied: langsmith<0.4,>=0.3.45 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.3.45)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.33)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.11.5)
# Collecting torch>=1.11.0 (from sentence-transformers>=2.6.0->langchain-huggingface)
#   Downloading torch-2.7.1-cp39-none-macosx_11_0_arm64.whl.metadata (29 kB)
# Collecting scikit-learn (from sentence-transformers>=2.6.0->langchain-huggingface)
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting scipy (from sentence-transformers>=2.6.0->langchain-huggingface)
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
# Collecting Pillow (from sentence-transformers>=2.6.0->langchain-huggingface)
#   Downloading pillow-11.2.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers>=4.39.0->langchain-huggingface) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from transformers>=4.39.0->langchain-huggingface) (2024.11.6)
# Collecting safetensors>=0.4.3 (from transformers>=4.39.0->langchain-huggingface)
#   Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2025.4.26)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: anyio in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.16.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface)
#   Using cached MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/karthikr/Desktop/Ongoing tasks/bot detection/venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.3.45->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.3.1)
# Downloading langchain_huggingface-0.2.0-py3-none-any.whl (27 kB)
# Downloading huggingface_hub-0.32.4-py3-none-any.whl (512 kB)
# Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 35.0 MB/s eta 0:00:00
# Downloading transformers-4.52.4-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 43.3 MB/s eta 0:00:00 0:00:01
# Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Downloading hf_xet-1.1.3-cp37-abi3-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 46.1 MB/s eta 0:00:00
# Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
# Downloading torch-2.7.1-cp39-none-macosx_11_0_arm64.whl (68.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 MB 53.0 MB/s eta 0:00:0000:0100:01
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading pillow-11.2.1-cp39-cp39-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 64.5 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 49.6 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 61.0 MB/s eta 0:00:00a 0:00:01
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 43.0 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.0 MB/s eta 0:00:00
# Using cached MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, threadpoolctl, sympy, scipy, safetensors, Pillow, networkx, MarkupSafe, joblib, hf-xet, fsspec, filelock, scikit-learn, jinja2, huggingface-hub, torch, tokenizers, transformers, sentence-transformers, langchain-huggingface
# Successfully installed MarkupSafe-3.0.2 Pillow-11.2.1 filelock-3.18.0 fsspec-2025.5.1 hf-xet-1.1.3 huggingface-hub-0.32.4 jinja2-3.1.6 joblib-1.5.1 langchain-huggingface-0.2.0 mpmath-1.3.0 networkx-3.2.1 safetensors-0.5.3 scikit-learn-1.6.1 scipy-1.13.1 sentence-transformers-4.1.0 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.21.1 torch-2.7.1 transformers-4.52.4
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
os.environ["GOOGLE_API_KEY"] = "AIzaSyDLM5D4QZPB-TOrVoT5PxzLbJg6fUHuCFI"

# %%
from langchain_community.embeddings import
